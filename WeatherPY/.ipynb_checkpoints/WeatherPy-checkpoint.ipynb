# %% [markdown]
# # WeatherPy
#
# ## Kevin Krause
# ## Module 6 Challenge
# ## May 11, 2023
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
import matplotlib.pyplot as plt
import scipy.stats as st
# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy 
## I had to run pip install citypy
from pprint import pprint

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
cities
# Out:
# Number of cities in the list: 605
# ['port-aux-francais',
#  'borgarnes',
#  'andergrove',
#  'stanley',
#  'chubbuck',
#  'adamstown',
#  'margaret river',
#  'blackmans bay',
#  'lebu',
#  'grytviken',
#  'bethel',
#  'tobelo',
#  'ormara',
#  'barcelos',
#  'lazaro cardenas',
#  'fale old settlement',
#  'mizdah',
#  'olonkinbyen',
#  'nkurenkuru',
#  'port lincoln',
#  'betio village',
#  'i-n-salah',
#  'murzuq',
#  'bredasdorp',
#  'nemuro',
#  'phan rang-thap cham',
#  'waitangi',
#  'tweed heads',
#  'pasni',
#  'edinburgh of the seven seas',
#  'vorgashor',
#  'utrik',
#  "chul'man",
#  'kingston',
#  'tolanaro',
#  'ust-nera',
#  'kill devil hills',
#  'launceston',
#  'letpandan',
#  'saipan',
#  'port mathurin',
#  'pacific grove',
#  'cidreira',
#  'puerto natales',
#  'hawaiian paradise park',
#  'yellowknife',
#  'taoudenni',
#  'georgetown',
#  'tiksi',
#  'atamyrat',
#  'zaraza',
#  'vingt cinq',
#  'chardara',
#  'palmares do sul',
#  'madera',
#  'aasiaat',
#  'rongelap',
#  'laguna',
#  'merke',
#  'ushuaia',
#  "'izbat al burj",
#  'muisne',
#  'okha',
#  'abrud',
#  'puerto ayora',
#  'boyolangu',
#  'gilgit',
#  'ornskoldsvik',
#  'longyearbyen',
#  'palapag',
#  'joao pinheiro',
#  'pustoshka',
#  'kirensk',
#  'khoyniki',
#  'isafjordur',
#  'guerrero negro',
#  'selfoss',
#  'kuyucak',
#  'queenstown',
#  'niesky',
#  'changli',
#  'ribeira grande',
#  'nadym',
#  'thompson',
#  'trairi',
#  'codrington',
#  'atafu village',
#  'fuvahmulah',
#  'ilulissat',
#  'norilsk',
#  'viedma',
#  'bilibino',
#  'turpan',
#  'carnarvon',
#  'acapulco de juarez',
#  'ziro',
#  'jamestown',
#  'juneau',
#  'pandan',
#  'majie',
#  'gazipasa',
#  'la passe',
#  'fort bragg',
#  'remire-montjoly',
#  "st. john's",
#  'cold lake',
#  'taiohae',
#  'wailua homesteads',
#  'ryotsu-minato',
#  'papatowai',
#  'invercargill',
#  'nizhneudinsk',
#  'tornio',
#  'avarua',
#  'nuuk',
#  "cooper's town",
#  'arteche',
#  'wohlen',
#  'kudahuvadhoo',
#  'albany',
#  'kerikeri',
#  'al shamkhah city',
#  'hamilton',
#  'nova vicosa',
#  'kirillov',
#  'west island',
#  'bireun',
#  'qaqortoq',
#  'dudinka',
#  'nogliki',
#  'tobi village',
#  'sharan',
#  'rawson',
#  'aswan',
#  'usogorsk',
#  'axim',
#  'broome',
#  "nuku'alofa",
#  'celestun',
#  'port augusta',
#  'kenai',
#  'port elizabeth',
#  'sao felix do xingu',
#  'keflavik',
#  'kabo',
#  'sinabang',
#  'sao joao da barra',
#  'mangrol',
#  'tobruk',
#  'lompoc',
#  'tupiza',
#  'motueka',
#  'colonia',
#  'martakert',
#  'macau',
#  'hermanus',
#  'itacare',
#  'huarmey',
#  'alofi',
#  'yuzhno-kurilsk',
#  'aykhal',
#  'morogoro',
#  'mhangura',
#  'florence',
#  'namibe',
#  'jurm',
#  'bandar lampung',
#  'sao francisco do sul',
#  'harstad',
#  'taro',
#  'grand falls-windsor',
#  'ridgecrest',
#  'nadi',
#  'cabo san lucas',
#  'hithadhoo',
#  'yuncheng',
#  'melekeok village',
#  'yeraliyev',
#  'lihue',
#  'el granada',
#  'hadibu',
#  'qamdo',
#  'anadyr',
#  'petropavlovsk-kamchatsky',
#  "kapa'a",
#  'san jose village',
#  'khandyga',
#  "muzayri'",
#  'nagqu',
#  'ramban',
#  'saldanha',
#  'zhangye',
#  'batikent',
#  'uturoa',
#  'mwinilunga',
#  'emerald',
#  'floro',
#  'ribeira brava',
#  'chonchi',
#  'cargados carajos',
#  'sonsorol village',
#  'udachny',
#  'calama',
#  'moree',
#  'ponta delgada',
#  'bartolome maso',
#  'box elder',
#  'port alfred',
#  'hasaki',
#  'dwarka',
#  'hanceville',
#  'badger',
#  'iqaluit',
#  'talnakh',
#  'monte alegre',
#  'mount gambier',
#  'encrucijada',
#  'afaahiti',
#  'puerto baquerizo moreno',
#  'leava',
#  'homnabad',
#  'labrador city',
#  'datong',
#  'mhamid',
#  'college',
#  'punta arenas',
#  'mana',
#  'touros',
#  'shushtar',
#  'vilyuchinsk',
#  'kargil',
#  'mandera',
#  'pukhrayan',
#  'nikolayevsk-on-amure',
#  'el nido',
#  'kargasok',
#  "nar'yan-mar",
#  'thunder bay',
#  'susuman',
#  'whitehorse',
#  'holualoa',
#  'visakhapatnam',
#  'tura',
#  'zhanaozen',
#  'balabac',
#  'pucon',
#  'kodar',
#  'borogontsy',
#  'arac',
#  'arraial do cabo',
#  'tucumcari',
#  'mundgod',
#  'namtsy',
#  'freetown',
#  'karatas',
#  'east palo alto',
#  'yamada',
#  'pithoragarh',
#  'porto novo',
#  'minas de marcona',
#  'tommot',
#  'zelenogorsk',
#  'qapqal',
#  'naze',
#  'valparai',
#  'vernon',
#  'alenquer',
#  'zhangatas',
#  'santiago de cuba',
#  'yoichi',
#  'ola',
#  'tazacorte',
#  'vadso',
#  'saint-francois',
#  'taltal',
#  'margate',
#  'cadale',
#  'greenville',
#  'pisco',
#  'korla',
#  'mazagao',
#  'saltillo',
#  'archidona',
#  'ndofane',
#  'prata',
#  'constantia',
#  'chanika',
#  'prado',
#  'alice springs',
#  'saratamata',
#  'argostolion',
#  'siwa oasis',
#  'qui nhon',
#  'steinbach',
#  'vorkuta',
#  'chui',
#  'gereida',
#  "la'ie",
#  'farafangana',
#  'aoulef',
#  'bousso',
#  'acarau',
#  'recani',
#  'coalcoman de vazquez pallares',
#  'kazalinsk',
#  'tomarza',
#  'tofol',
#  'belogorsk',
#  'severo-yeniseyskiy',
#  'vilyuysk',
#  'tuburan',
#  'ouarzazat',
#  'island harbour',
#  'kodiak',
#  'aljezur',
#  'valdivia',
#  'den burg',
#  'happy valley-goose bay',
#  'nova sintra',
#  'kafir qala',
#  'sarina',
#  'sampit',
#  'at-bashi',
#  'mariehamn',
#  'sierra grande',
#  'piacabucu',
#  'lenti',
#  'escanaba',
#  "kil'mez'",
#  'tangalle',
#  'hilo',
#  'champerico',
#  'flekkefjord',
#  'wynyard',
#  'salym',
#  'mahina',
#  'dryden',
#  'ancud',
#  'kulob',
#  'archangelos',
#  'iskateley',
#  'kardla',
#  'meadow lakes',
#  'midvagur',
#  'paranavai',
#  'karwar',
#  'luang namtha',
#  'ciudad lazaro cardenas',
#  'bereznik',
#  'vila franca do campo',
#  'yatou',
#  'tazovsky',
#  'kabale',
#  'camiri',
#  'napili-honokowai',
#  'kinkala',
#  'lata',
#  'kenora',
#  'kijang',
#  'bengkulu',
#  'saudarkrokur',
#  "'ohonua",
#  'kindu',
#  'murghob',
#  'fortaleza',
#  'stjordalshalsen',
#  'bordj ghdir',
#  'tamanrasset',
#  'la ronge',
#  'andilamena',
#  'port shepstone',
#  'labuan',
#  'behshahr',
#  'luau',
#  'trenggalek',
#  'poronaysk',
#  'laishevo',
#  'semporna',
#  'kattivakkam',
#  "maych'ew",
#  'linxia chengguanzhen',
#  'sao vicente',
#  'nabire',
#  'labasa',
#  'enewetak',
#  'kavaratti',
#  'detroit lakes',
#  'luanda',
#  'hohhot',
#  'quang ngai',
#  'kyzyl-suu',
#  'puerto lempira',
#  'alesund',
#  'ahau',
#  'tinajo',
#  'bratca',
#  'north bend',
#  'tekirova',
#  'coahuayana de hidalgo',
#  'sinop',
#  'chabahar',
#  'chibougamau',
#  'nema',
#  'mesquite',
#  'malpica',
#  'karachi',
#  'orai',
#  'port blair',
#  'east london',
#  'selkirk',
#  'yagry',
#  'klyuchi',
#  'nitra',
#  'hyesan',
#  'praia da vitoria',
#  'kirsanov',
#  'kuta',
#  'karratha',
#  'santa flavia',
#  'mankera',
#  'bryne',
#  'ascencion de guarayos',
#  'el calafate',
#  'miedzyzdroje',
#  'hobyo',
#  'fisterra',
#  'okakarara',
#  'mukah',
#  'telavi',
#  'antonio enes',
#  'nola',
#  'drummondville',
#  'port douglas',
#  'tsiombe',
#  'walvis bay',
#  'yanzhou',
#  'salekhard',
#  'puerto san carlos',
#  'saynshand',
#  "mil'kovo",
#  'madalena',
#  'saint-philippe',
#  'sitka',
#  'mugia',
#  'kabin buri',
#  'hammerfest',
#  'portland',
#  'san patricio',
#  'coquimbo',
#  'waynesboro',
#  'bontang',
#  'amasra',
#  'santa ana',
#  'paita',
#  'kristinehamn',
#  'bandipura',
#  'point pedro',
#  'carbonear',
#  'alaghsas',
#  'karymskoye',
#  'sambava',
#  'blenheim',
#  'predeal',
#  'posto fiscal rolim de moura',
#  'vroomshoop',
#  'lerwick',
#  'ruidoso',
#  'altay',
#  'mount pearl',
#  'saint-pierre',
#  'bandarbeyla',
#  'shawinigan',
#  'roma',
#  'kiunga',
#  'labuan bajo',
#  'kazincbarcika',
#  'chingirlau',
#  'nuevo ideal',
#  'swakopmund',
#  'dakhla',
#  'campos belos',
#  'tenenkou',
#  'gadzhiyevo',
#  'pitimbu',
#  'tannum sands',
#  'timimoun',
#  'altai',
#  'polyarnyy',
#  "oltinko'l",
#  'tromso',
#  'bedesa',
#  'outapi',
#  'butha-buthe',
#  'vera',
#  'flying fish cove',
#  'boyalik',
#  'taulaga',
#  'zaozersk',
#  'conduaga',
#  'bazarnyye mataki',
#  "ma'an",
#  'kamennogorsk',
#  'tilisarao',
#  'hotan',
#  'cabedelo',
#  'cole harbour',
#  'cienfuegos',
#  'sooke',
#  'frontino',
#  'amealco',
#  'cromer',
#  'stranraer',
#  'meulaboh',
#  'calingasta',
#  'merlo',
#  'rikaze',
#  'angaur state',
#  'christchurch',
#  'fort st. john',
#  "port saint john's",
#  'arkalyk',
#  'arraias',
#  'corfu',
#  'volodarskiy',
#  'robore',
#  'berezovyy',
#  'taipei',
#  'scone',
#  'tukrah',
#  'ostersund',
#  'sakaiminato',
#  'san jose de jachal',
#  'homer',
#  'kolpashevo',
#  'phalaborwa',
#  'baiyin',
#  'big bend',
#  'toliara',
#  'serhiyivka',
#  'horasan',
#  'maebaru-chuo',
#  'chiredzi',
#  'eyl',
#  'omsk',
#  'yelm',
#  'parkes',
#  'vielsalm',
#  'badiyah',
#  'ambodifotatra',
#  'ruy barbosa',
#  'argo',
#  'usinsk',
#  'yeed',
#  'benjamin constant',
#  'ocean city',
#  'alpine',
#  'quatre cocos',
#  'itapetinga',
#  'quellon',
#  'calatayud',
#  'nouadhibou',
#  'olinda',
#  'luderitz',
#  'ghanzi',
#  'kapuskasing',
#  'cockburn town',
#  'veraval',
#  'tual',
#  'tralee',
#  'ta`u',
#  'sydney',
#  'yeniseysk',
#  'kilindoni',
#  'takamaka',
#  'yeosu',
#  'pangody',
#  'colby',
#  'qarazhal',
#  'lauro de freitas',
#  'isola di capo rizzuto',
#  'oliveira dos brejinhos',
#  'weno',
#  'lobujya',
#  'lubang',
#  'valparaiso',
#  'azul',
#  'aldinga beach',
#  'sunland park',
#  'petrolina',
#  'talara',
#  'al qitena',
#  'waingapu',
#  'fabens',
#  'yugo-kamskiy',
#  'tarakan',
#  'omdurman',
#  'albertina',
#  'manta',
#  'callao',
#  'kiffa',
#  'as sulayyil',
#  'magadan',
#  'singkil',
#  'shenkursk',
#  'abu jibeha']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %% [markdown]
# #  KEVIN START HERE

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
#   city_url = # YOUR CODE HERE
#  Kevin code here ******************
    city_url = url + "appid=" + weather_api_key + "&q=" + city   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
#  Kevin code here **********************************
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
#  End Kevin Code **********************************************
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                         "Max Temp": city_max_temp - 273.15,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | borgarnes
# Processing Record 3 of Set 1 | andergrove
# Processing Record 4 of Set 1 | stanley
# Processing Record 5 of Set 1 | chubbuck
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | margaret river
# Processing Record 8 of Set 1 | blackmans bay
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | tobelo
# Processing Record 13 of Set 1 | ormara
# Processing Record 14 of Set 1 | barcelos
# Processing Record 15 of Set 1 | lazaro cardenas
# Processing Record 16 of Set 1 | fale old settlement
# Processing Record 17 of Set 1 | mizdah
# Processing Record 18 of Set 1 | olonkinbyen
# Processing Record 19 of Set 1 | nkurenkuru
# City not found. Skipping...
# Processing Record 20 of Set 1 | port lincoln
# Processing Record 21 of Set 1 | betio village
# Processing Record 22 of Set 1 | i-n-salah
# Processing Record 23 of Set 1 | murzuq
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | nemuro
# Processing Record 26 of Set 1 | phan rang-thap cham
# Processing Record 27 of Set 1 | waitangi
# Processing Record 28 of Set 1 | tweed heads
# Processing Record 29 of Set 1 | pasni
# Processing Record 30 of Set 1 | edinburgh of the seven seas
# Processing Record 31 of Set 1 | vorgashor
# Processing Record 32 of Set 1 | utrik
# Processing Record 33 of Set 1 | chul'man
# Processing Record 34 of Set 1 | kingston
# Processing Record 35 of Set 1 | tolanaro
# Processing Record 36 of Set 1 | ust-nera
# Processing Record 37 of Set 1 | kill devil hills
# Processing Record 38 of Set 1 | launceston
# Processing Record 39 of Set 1 | letpandan
# Processing Record 40 of Set 1 | saipan
# Processing Record 41 of Set 1 | port mathurin
# Processing Record 42 of Set 1 | pacific grove
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | puerto natales
# Processing Record 45 of Set 1 | hawaiian paradise park
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | taoudenni
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | atamyrat
# Processing Record 0 of Set 2 | zaraza
# Processing Record 1 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 2 | chardara
# Processing Record 3 of Set 2 | palmares do sul
# Processing Record 4 of Set 2 | madera
# Processing Record 5 of Set 2 | aasiaat
# Processing Record 6 of Set 2 | rongelap
# Processing Record 7 of Set 2 | laguna
# Processing Record 8 of Set 2 | merke
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | 'izbat al burj
# City not found. Skipping...
# Processing Record 11 of Set 2 | muisne
# Processing Record 12 of Set 2 | okha
# Processing Record 13 of Set 2 | abrud
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | boyolangu
# Processing Record 16 of Set 2 | gilgit
# Processing Record 17 of Set 2 | ornskoldsvik
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | palapag
# Processing Record 20 of Set 2 | joao pinheiro
# Processing Record 21 of Set 2 | pustoshka
# Processing Record 22 of Set 2 | kirensk
# Processing Record 23 of Set 2 | khoyniki
# Processing Record 24 of Set 2 | isafjordur
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | selfoss
# Processing Record 27 of Set 2 | kuyucak
# Processing Record 28 of Set 2 | queenstown
# Processing Record 29 of Set 2 | niesky
# Processing Record 30 of Set 2 | changli
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | nadym
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | trairi
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | atafu village
# Processing Record 37 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | norilsk
# Processing Record 40 of Set 2 | viedma
# Processing Record 41 of Set 2 | bilibino
# Processing Record 42 of Set 2 | turpan
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | acapulco de juarez
# Processing Record 45 of Set 2 | ziro
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | juneau
# Processing Record 48 of Set 2 | pandan
# Processing Record 49 of Set 2 | majie
# Processing Record 0 of Set 3 | gazipasa
# Processing Record 1 of Set 3 | la passe
# Processing Record 2 of Set 3 | fort bragg
# Processing Record 3 of Set 3 | remire-montjoly
# Processing Record 4 of Set 3 | st. john's
# Processing Record 5 of Set 3 | cold lake
# Processing Record 6 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 3 | wailua homesteads
# Processing Record 8 of Set 3 | ryotsu-minato
# Processing Record 9 of Set 3 | papatowai
# Processing Record 10 of Set 3 | invercargill
# Processing Record 11 of Set 3 | nizhneudinsk
# Processing Record 12 of Set 3 | tornio
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | nuuk
# Processing Record 15 of Set 3 | cooper's town
# Processing Record 16 of Set 3 | arteche
# Processing Record 17 of Set 3 | wohlen
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | albany
# Processing Record 20 of Set 3 | kerikeri
# Processing Record 21 of Set 3 | al shamkhah city
# City not found. Skipping...
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | nova vicosa
# Processing Record 24 of Set 3 | kirillov
# Processing Record 25 of Set 3 | west island
# Processing Record 26 of Set 3 | bireun
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | dudinka
# Processing Record 29 of Set 3 | nogliki
# Processing Record 30 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 31 of Set 3 | sharan
# Processing Record 32 of Set 3 | rawson
# Processing Record 33 of Set 3 | aswan
# Processing Record 34 of Set 3 | usogorsk
# Processing Record 35 of Set 3 | axim
# Processing Record 36 of Set 3 | broome
# Processing Record 37 of Set 3 | nuku'alofa
# Processing Record 38 of Set 3 | celestun
# Processing Record 39 of Set 3 | port augusta
# Processing Record 40 of Set 3 | kenai
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | sao felix do xingu
# Processing Record 43 of Set 3 | keflavik
# Processing Record 44 of Set 3 | kabo
# Processing Record 45 of Set 3 | sinabang
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | mangrol
# Processing Record 48 of Set 3 | tobruk
# Processing Record 49 of Set 3 | lompoc
# Processing Record 0 of Set 4 | tupiza
# Processing Record 1 of Set 4 | motueka
# Processing Record 2 of Set 4 | colonia
# Processing Record 3 of Set 4 | martakert
# Processing Record 4 of Set 4 | macau
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | itacare
# Processing Record 7 of Set 4 | huarmey
# Processing Record 8 of Set 4 | alofi
# Processing Record 9 of Set 4 | yuzhno-kurilsk
# Processing Record 10 of Set 4 | aykhal
# Processing Record 11 of Set 4 | morogoro
# Processing Record 12 of Set 4 | mhangura
# Processing Record 13 of Set 4 | florence
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | jurm
# Processing Record 16 of Set 4 | bandar lampung
# Processing Record 17 of Set 4 | sao francisco do sul
# Processing Record 18 of Set 4 | harstad
# Processing Record 19 of Set 4 | taro
# Processing Record 20 of Set 4 | grand falls-windsor
# Processing Record 21 of Set 4 | ridgecrest
# Processing Record 22 of Set 4 | nadi
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | yuncheng
# Processing Record 26 of Set 4 | melekeok village
# Processing Record 27 of Set 4 | yeraliyev
# Processing Record 28 of Set 4 | lihue
# Processing Record 29 of Set 4 | el granada
# Processing Record 30 of Set 4 | hadibu
# Processing Record 31 of Set 4 | qamdo
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 34 of Set 4 | kapa'a
# Processing Record 35 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 36 of Set 4 | khandyga
# Processing Record 37 of Set 4 | muzayri'
# City not found. Skipping...
# Processing Record 38 of Set 4 | nagqu
# Processing Record 39 of Set 4 | ramban
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | zhangye
# Processing Record 42 of Set 4 | batikent
# Processing Record 43 of Set 4 | uturoa
# Processing Record 44 of Set 4 | mwinilunga
# Processing Record 45 of Set 4 | emerald
# Processing Record 46 of Set 4 | floro
# Processing Record 47 of Set 4 | ribeira brava
# Processing Record 48 of Set 4 | chonchi
# Processing Record 49 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 0 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 1 of Set 5 | udachny
# Processing Record 2 of Set 5 | calama
# Processing Record 3 of Set 5 | moree
# Processing Record 4 of Set 5 | ponta delgada
# Processing Record 5 of Set 5 | bartolome maso
# City not found. Skipping...
# Processing Record 6 of Set 5 | box elder
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | dwarka
# Processing Record 10 of Set 5 | hanceville
# Processing Record 11 of Set 5 | badger
# Processing Record 12 of Set 5 | iqaluit
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | monte alegre
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | encrucijada
# Processing Record 17 of Set 5 | afaahiti
# Processing Record 18 of Set 5 | puerto baquerizo moreno
# Processing Record 19 of Set 5 | leava
# Processing Record 20 of Set 5 | homnabad
# Processing Record 21 of Set 5 | labrador city
# Processing Record 22 of Set 5 | datong
# Processing Record 23 of Set 5 | mhamid
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | punta arenas
# Processing Record 26 of Set 5 | mana
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | shushtar
# Processing Record 29 of Set 5 | vilyuchinsk
# Processing Record 30 of Set 5 | kargil
# Processing Record 31 of Set 5 | mandera
# Processing Record 32 of Set 5 | pukhrayan
# Processing Record 33 of Set 5 | nikolayevsk-on-amure
# Processing Record 34 of Set 5 | el nido
# Processing Record 35 of Set 5 | kargasok
# Processing Record 36 of Set 5 | nar'yan-mar
# Processing Record 37 of Set 5 | thunder bay
# Processing Record 38 of Set 5 | susuman
# Processing Record 39 of Set 5 | whitehorse
# Processing Record 40 of Set 5 | holualoa
# Processing Record 41 of Set 5 | visakhapatnam
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | zhanaozen
# Processing Record 44 of Set 5 | balabac
# Processing Record 45 of Set 5 | pucon
# Processing Record 46 of Set 5 | kodar
# Processing Record 47 of Set 5 | borogontsy
# Processing Record 48 of Set 5 | arac
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 0 of Set 6 | tucumcari
# Processing Record 1 of Set 6 | mundgod
# Processing Record 2 of Set 6 | namtsy
# Processing Record 3 of Set 6 | freetown
# Processing Record 4 of Set 6 | karatas
# Processing Record 5 of Set 6 | east palo alto
# Processing Record 6 of Set 6 | yamada
# Processing Record 7 of Set 6 | pithoragarh
# Processing Record 8 of Set 6 | porto novo
# Processing Record 9 of Set 6 | minas de marcona
# Processing Record 10 of Set 6 | tommot
# Processing Record 11 of Set 6 | zelenogorsk
# Processing Record 12 of Set 6 | qapqal
# City not found. Skipping...
# Processing Record 13 of Set 6 | naze
# Processing Record 14 of Set 6 | valparai
# Processing Record 15 of Set 6 | vernon
# Processing Record 16 of Set 6 | alenquer
# Processing Record 17 of Set 6 | zhangatas
# Processing Record 18 of Set 6 | santiago de cuba
# Processing Record 19 of Set 6 | yoichi
# Processing Record 20 of Set 6 | ola
# Processing Record 21 of Set 6 | tazacorte
# Processing Record 22 of Set 6 | vadso
# Processing Record 23 of Set 6 | saint-francois
# Processing Record 24 of Set 6 | taltal
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | cadale
# Processing Record 27 of Set 6 | greenville
# Processing Record 28 of Set 6 | pisco
# Processing Record 29 of Set 6 | korla
# Processing Record 30 of Set 6 | mazagao
# Processing Record 31 of Set 6 | saltillo
# Processing Record 32 of Set 6 | archidona
# Processing Record 33 of Set 6 | ndofane
# Processing Record 34 of Set 6 | prata
# Processing Record 35 of Set 6 | constantia
# Processing Record 36 of Set 6 | chanika
# Processing Record 37 of Set 6 | prado
# Processing Record 38 of Set 6 | alice springs
# Processing Record 39 of Set 6 | saratamata
# City not found. Skipping...
# Processing Record 40 of Set 6 | argostolion
# Processing Record 41 of Set 6 | siwa oasis
# Processing Record 42 of Set 6 | qui nhon
# Processing Record 43 of Set 6 | steinbach
# Processing Record 44 of Set 6 | vorkuta
# Processing Record 45 of Set 6 | chui
# Processing Record 46 of Set 6 | gereida
# Processing Record 47 of Set 6 | la'ie
# Processing Record 48 of Set 6 | farafangana
# Processing Record 49 of Set 6 | aoulef
# Processing Record 0 of Set 7 | bousso
# Processing Record 1 of Set 7 | acarau
# Processing Record 2 of Set 7 | recani
# Processing Record 3 of Set 7 | coalcoman de vazquez pallares
# Processing Record 4 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 7 | tomarza
# Processing Record 6 of Set 7 | tofol
# Processing Record 7 of Set 7 | belogorsk
# Processing Record 8 of Set 7 | severo-yeniseyskiy
# Processing Record 9 of Set 7 | vilyuysk
# Processing Record 10 of Set 7 | tuburan
# Processing Record 11 of Set 7 | ouarzazat
# Processing Record 12 of Set 7 | island harbour
# Processing Record 13 of Set 7 | kodiak
# Processing Record 14 of Set 7 | aljezur
# Processing Record 15 of Set 7 | valdivia
# Processing Record 16 of Set 7 | den burg
# Processing Record 17 of Set 7 | happy valley-goose bay
# Processing Record 18 of Set 7 | nova sintra
# Processing Record 19 of Set 7 | kafir qala
# Processing Record 20 of Set 7 | sarina
# Processing Record 21 of Set 7 | sampit
# Processing Record 22 of Set 7 | at-bashi
# Processing Record 23 of Set 7 | mariehamn
# Processing Record 24 of Set 7 | sierra grande
# Processing Record 25 of Set 7 | piacabucu
# Processing Record 26 of Set 7 | lenti
# Processing Record 27 of Set 7 | escanaba
# Processing Record 28 of Set 7 | kil'mez'
# City not found. Skipping...
# Processing Record 29 of Set 7 | tangalle
# Processing Record 30 of Set 7 | hilo
# Processing Record 31 of Set 7 | champerico
# Processing Record 32 of Set 7 | flekkefjord
# Processing Record 33 of Set 7 | wynyard
# Processing Record 34 of Set 7 | salym
# Processing Record 35 of Set 7 | mahina
# Processing Record 36 of Set 7 | dryden
# Processing Record 37 of Set 7 | ancud
# Processing Record 38 of Set 7 | kulob
# Processing Record 39 of Set 7 | archangelos
# Processing Record 40 of Set 7 | iskateley
# Processing Record 41 of Set 7 | kardla
# Processing Record 42 of Set 7 | meadow lakes
# Processing Record 43 of Set 7 | midvagur
# Processing Record 44 of Set 7 | paranavai
# Processing Record 45 of Set 7 | karwar
# Processing Record 46 of Set 7 | luang namtha
# Processing Record 47 of Set 7 | ciudad lazaro cardenas
# Processing Record 48 of Set 7 | bereznik
# Processing Record 49 of Set 7 | vila franca do campo
# Processing Record 0 of Set 8 | yatou
# Processing Record 1 of Set 8 | tazovsky
# Processing Record 2 of Set 8 | kabale
# Processing Record 3 of Set 8 | camiri
# Processing Record 4 of Set 8 | napili-honokowai
# Processing Record 5 of Set 8 | kinkala
# Processing Record 6 of Set 8 | lata
# Processing Record 7 of Set 8 | kenora
# Processing Record 8 of Set 8 | kijang
# Processing Record 9 of Set 8 | bengkulu
# Processing Record 10 of Set 8 | saudarkrokur
# Processing Record 11 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 8 | kindu
# Processing Record 13 of Set 8 | murghob
# Processing Record 14 of Set 8 | fortaleza
# Processing Record 15 of Set 8 | stjordalshalsen
# Processing Record 16 of Set 8 | bordj ghdir
# Processing Record 17 of Set 8 | tamanrasset
# Processing Record 18 of Set 8 | la ronge
# Processing Record 19 of Set 8 | andilamena
# Processing Record 20 of Set 8 | port shepstone
# Processing Record 21 of Set 8 | labuan
# Processing Record 22 of Set 8 | behshahr
# Processing Record 23 of Set 8 | luau
# Processing Record 24 of Set 8 | trenggalek
# Processing Record 25 of Set 8 | poronaysk
# Processing Record 26 of Set 8 | laishevo
# Processing Record 27 of Set 8 | semporna
# Processing Record 28 of Set 8 | kattivakkam
# Processing Record 29 of Set 8 | maych'ew
# Processing Record 30 of Set 8 | linxia chengguanzhen
# Processing Record 31 of Set 8 | sao vicente
# Processing Record 32 of Set 8 | nabire
# Processing Record 33 of Set 8 | labasa
# Processing Record 34 of Set 8 | enewetak
# Processing Record 35 of Set 8 | kavaratti
# Processing Record 36 of Set 8 | detroit lakes
# Processing Record 37 of Set 8 | luanda
# Processing Record 38 of Set 8 | hohhot
# Processing Record 39 of Set 8 | quang ngai
# Processing Record 40 of Set 8 | kyzyl-suu
# Processing Record 41 of Set 8 | puerto lempira
# Processing Record 42 of Set 8 | alesund
# Processing Record 43 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 44 of Set 8 | tinajo
# Processing Record 45 of Set 8 | bratca
# Processing Record 46 of Set 8 | north bend
# Processing Record 47 of Set 8 | tekirova
# Processing Record 48 of Set 8 | coahuayana de hidalgo
# Processing Record 49 of Set 8 | sinop
# Processing Record 0 of Set 9 | chabahar
# Processing Record 1 of Set 9 | chibougamau
# Processing Record 2 of Set 9 | nema
# Processing Record 3 of Set 9 | mesquite
# Processing Record 4 of Set 9 | malpica
# Processing Record 5 of Set 9 | karachi
# Processing Record 6 of Set 9 | orai
# Processing Record 7 of Set 9 | port blair
# Processing Record 8 of Set 9 | east london
# Processing Record 9 of Set 9 | selkirk
# Processing Record 10 of Set 9 | yagry
# City not found. Skipping...
# Processing Record 11 of Set 9 | klyuchi
# Processing Record 12 of Set 9 | nitra
# Processing Record 13 of Set 9 | hyesan
# Processing Record 14 of Set 9 | praia da vitoria
# Processing Record 15 of Set 9 | kirsanov
# Processing Record 16 of Set 9 | kuta
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | santa flavia
# Processing Record 19 of Set 9 | mankera
# Processing Record 20 of Set 9 | bryne
# Processing Record 21 of Set 9 | ascencion de guarayos
# City not found. Skipping...
# Processing Record 22 of Set 9 | el calafate
# Processing Record 23 of Set 9 | miedzyzdroje
# Processing Record 24 of Set 9 | hobyo
# Processing Record 25 of Set 9 | fisterra
# Processing Record 26 of Set 9 | okakarara
# Processing Record 27 of Set 9 | mukah
# City not found. Skipping...
# Processing Record 28 of Set 9 | telavi
# Processing Record 29 of Set 9 | antonio enes
# Processing Record 30 of Set 9 | nola
# Processing Record 31 of Set 9 | drummondville
# Processing Record 32 of Set 9 | port douglas
# Processing Record 33 of Set 9 | tsiombe
# Processing Record 34 of Set 9 | walvis bay
# Processing Record 35 of Set 9 | yanzhou
# Processing Record 36 of Set 9 | salekhard
# Processing Record 37 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 38 of Set 9 | saynshand
# Processing Record 39 of Set 9 | mil'kovo
# Processing Record 40 of Set 9 | madalena
# Processing Record 41 of Set 9 | saint-philippe
# Processing Record 42 of Set 9 | sitka
# Processing Record 43 of Set 9 | mugia
# Processing Record 44 of Set 9 | kabin buri
# Processing Record 45 of Set 9 | hammerfest
# Processing Record 46 of Set 9 | portland
# Processing Record 47 of Set 9 | san patricio
# Processing Record 48 of Set 9 | coquimbo
# Processing Record 49 of Set 9 | waynesboro
# Processing Record 0 of Set 10 | bontang
# Processing Record 1 of Set 10 | amasra
# Processing Record 2 of Set 10 | santa ana
# Processing Record 3 of Set 10 | paita
# Processing Record 4 of Set 10 | kristinehamn
# Processing Record 5 of Set 10 | bandipura
# Processing Record 6 of Set 10 | point pedro
# Processing Record 7 of Set 10 | carbonear
# Processing Record 8 of Set 10 | alaghsas
# Processing Record 9 of Set 10 | karymskoye
# Processing Record 10 of Set 10 | sambava
# Processing Record 11 of Set 10 | blenheim
# Processing Record 12 of Set 10 | predeal
# Processing Record 13 of Set 10 | posto fiscal rolim de moura
# Processing Record 14 of Set 10 | vroomshoop
# Processing Record 15 of Set 10 | lerwick
# Processing Record 16 of Set 10 | ruidoso
# Processing Record 17 of Set 10 | altay
# Processing Record 18 of Set 10 | mount pearl
# Processing Record 19 of Set 10 | saint-pierre
# Processing Record 20 of Set 10 | bandarbeyla
# Processing Record 21 of Set 10 | shawinigan
# Processing Record 22 of Set 10 | roma
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | labuan bajo
# Processing Record 25 of Set 10 | kazincbarcika
# Processing Record 26 of Set 10 | chingirlau
# Processing Record 27 of Set 10 | nuevo ideal
# Processing Record 28 of Set 10 | swakopmund
# Processing Record 29 of Set 10 | dakhla
# Processing Record 30 of Set 10 | campos belos
# Processing Record 31 of Set 10 | tenenkou
# Processing Record 32 of Set 10 | gadzhiyevo
# Processing Record 33 of Set 10 | pitimbu
# Processing Record 34 of Set 10 | tannum sands
# Processing Record 35 of Set 10 | timimoun
# Processing Record 36 of Set 10 | altai
# Processing Record 37 of Set 10 | polyarnyy
# Processing Record 38 of Set 10 | oltinko'l
# Processing Record 39 of Set 10 | tromso
# Processing Record 40 of Set 10 | bedesa
# Processing Record 41 of Set 10 | outapi
# City not found. Skipping...
# Processing Record 42 of Set 10 | butha-buthe
# Processing Record 43 of Set 10 | vera
# Processing Record 44 of Set 10 | flying fish cove
# Processing Record 45 of Set 10 | boyalik
# Processing Record 46 of Set 10 | taulaga
# Processing Record 47 of Set 10 | zaozersk
# Processing Record 48 of Set 10 | conduaga
# Processing Record 49 of Set 10 | bazarnyye mataki
# Processing Record 0 of Set 11 | ma'an
# Processing Record 1 of Set 11 | kamennogorsk
# Processing Record 2 of Set 11 | tilisarao
# Processing Record 3 of Set 11 | hotan
# Processing Record 4 of Set 11 | cabedelo
# Processing Record 5 of Set 11 | cole harbour
# Processing Record 6 of Set 11 | cienfuegos
# Processing Record 7 of Set 11 | sooke
# Processing Record 8 of Set 11 | frontino
# Processing Record 9 of Set 11 | amealco
# Processing Record 10 of Set 11 | cromer
# Processing Record 11 of Set 11 | stranraer
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | calingasta
# Processing Record 14 of Set 11 | merlo
# Processing Record 15 of Set 11 | rikaze
# Processing Record 16 of Set 11 | angaur state
# Processing Record 17 of Set 11 | christchurch
# Processing Record 18 of Set 11 | fort st. john
# Processing Record 19 of Set 11 | port saint john's
# Processing Record 20 of Set 11 | arkalyk
# Processing Record 21 of Set 11 | arraias
# Processing Record 22 of Set 11 | corfu
# Processing Record 23 of Set 11 | volodarskiy
# Processing Record 24 of Set 11 | robore
# Processing Record 25 of Set 11 | berezovyy
# Processing Record 26 of Set 11 | taipei
# Processing Record 27 of Set 11 | scone
# Processing Record 28 of Set 11 | tukrah
# Processing Record 29 of Set 11 | ostersund
# Processing Record 30 of Set 11 | sakaiminato
# Processing Record 31 of Set 11 | san jose de jachal
# Processing Record 32 of Set 11 | homer
# Processing Record 33 of Set 11 | kolpashevo
# Processing Record 34 of Set 11 | phalaborwa
# Processing Record 35 of Set 11 | baiyin
# Processing Record 36 of Set 11 | big bend
# Processing Record 37 of Set 11 | toliara
# Processing Record 38 of Set 11 | serhiyivka
# Processing Record 39 of Set 11 | horasan
# Processing Record 40 of Set 11 | maebaru-chuo
# Processing Record 41 of Set 11 | chiredzi
# Processing Record 42 of Set 11 | eyl
# Processing Record 43 of Set 11 | omsk
# Processing Record 44 of Set 11 | yelm
# Processing Record 45 of Set 11 | parkes
# Processing Record 46 of Set 11 | vielsalm
# Processing Record 47 of Set 11 | badiyah
# Processing Record 48 of Set 11 | ambodifotatra
# Processing Record 49 of Set 11 | ruy barbosa
# Processing Record 0 of Set 12 | argo
# Processing Record 1 of Set 12 | usinsk
# Processing Record 2 of Set 12 | yeed
# Processing Record 3 of Set 12 | benjamin constant
# Processing Record 4 of Set 12 | ocean city
# Processing Record 5 of Set 12 | alpine
# Processing Record 6 of Set 12 | quatre cocos
# Processing Record 7 of Set 12 | itapetinga
# Processing Record 8 of Set 12 | quellon
# Processing Record 9 of Set 12 | calatayud
# Processing Record 10 of Set 12 | nouadhibou
# Processing Record 11 of Set 12 | olinda
# Processing Record 12 of Set 12 | luderitz
# Processing Record 13 of Set 12 | ghanzi
# Processing Record 14 of Set 12 | kapuskasing
# Processing Record 15 of Set 12 | cockburn town
# Processing Record 16 of Set 12 | veraval
# Processing Record 17 of Set 12 | tual
# Processing Record 18 of Set 12 | tralee
# Processing Record 19 of Set 12 | ta`u
# Processing Record 20 of Set 12 | sydney
# Processing Record 21 of Set 12 | yeniseysk
# Processing Record 22 of Set 12 | kilindoni
# Processing Record 23 of Set 12 | takamaka
# City not found. Skipping...
# Processing Record 24 of Set 12 | yeosu
# Processing Record 25 of Set 12 | pangody
# Processing Record 26 of Set 12 | colby
# Processing Record 27 of Set 12 | qarazhal
# Processing Record 28 of Set 12 | lauro de freitas
# Processing Record 29 of Set 12 | isola di capo rizzuto
# Processing Record 30 of Set 12 | oliveira dos brejinhos
# Processing Record 31 of Set 12 | weno
# Processing Record 32 of Set 12 | lobujya
# Processing Record 33 of Set 12 | lubang
# Processing Record 34 of Set 12 | valparaiso
# Processing Record 35 of Set 12 | azul
# Processing Record 36 of Set 12 | aldinga beach
# Processing Record 37 of Set 12 | sunland park
# Processing Record 38 of Set 12 | petrolina
# Processing Record 39 of Set 12 | talara
# Processing Record 40 of Set 12 | al qitena
# Processing Record 41 of Set 12 | waingapu
# Processing Record 42 of Set 12 | fabens
# Processing Record 43 of Set 12 | yugo-kamskiy
# Processing Record 44 of Set 12 | tarakan
# Processing Record 45 of Set 12 | omdurman
# Processing Record 46 of Set 12 | albertina
# Processing Record 47 of Set 12 | manta
# Processing Record 48 of Set 12 | callao
# Processing Record 49 of Set 12 | kiffa
# Processing Record 0 of Set 13 | as sulayyil
# Processing Record 1 of Set 13 | magadan
# Processing Record 2 of Set 13 | singkil
# Processing Record 3 of Set 13 | shenkursk
# Processing Record 4 of Set 13 | abu jibeha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
# Kevin Code
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      5.85        96         100
# 1          borgarnes  64.5383  -21.9206     10.03        83         100
# 2         andergrove -21.0833  149.1833     10.36        57          63
# 3            stanley  54.8680   -1.6985     14.29        85          20
# 4           chubbuck  42.9208 -112.4661     12.13        56           0
#
#    Wind Speed Country        Date
# 0       10.29      TF  1683659500
# 1        1.66      IS  1683659500
# 2        4.99      AU  1683659500
# 3        1.03      GB  1683659500
# 4        3.60      US  1683659500

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.85        96         100
# 1                borgarnes  64.5383  -21.9206     10.03        83         100
# 2               andergrove -21.0833  149.1833     10.36        57          63
# 3                  stanley  54.8680   -1.6985     14.29        85          20
# 4                 chubbuck  42.9208 -112.4661     12.13        56           0
#
#          Wind Speed Country        Date
# City_ID
# 0             10.29      TF  1683659500
# 1              1.66      IS  1683659500
# 2              4.99      AU  1683659500
# 3              1.03      GB  1683659500
# 4              3.60      US  1683659500

# %%
city_data_df.shape
# Out:
# (581, 9)

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
#  Kevin Code
ax1 = city_data_df.plot.scatter(x='Lat',
                       y='Max Temp',
                       c='DarkBlue',
                       title='City Latitude vs. Max Temperature (2023-05-09)')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
ax1 = city_data_df.plot.scatter(x='Lat',
                       y='Humidity',
                       c='DarkBlue',
                       title='City Latitude vs. Humidty (2023-05-09)')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
ax1 = city_data_df.plot.scatter(x='Lat',
                       y='Cloudiness',
                       c='DarkBlue',
                       title='City Latitude vs. Cloudiness (2023-05-09)')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
ax1 = city_data_df.plot.scatter(x='Lat',
                       y='Wind Speed',
                       c='DarkBlue',
                       title='City Latitude vs. Wind Speed (2023-05-09)')
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.85        96         100
# 1                borgarnes  64.5383  -21.9206     10.03        83         100
# 2               andergrove -21.0833  149.1833     10.36        57          63
# 3                  stanley  54.8680   -1.6985     14.29        85          20
# 4                 chubbuck  42.9208 -112.4661     12.13        56           0
#
#          Wind Speed Country        Date
# City_ID
# 0             10.29      TF  1683659500
# 1              1.66      IS  1683659500
# 2              4.99      AU  1683659500
# 3              1.03      GB  1683659500
# 4              3.60      US  1683659500

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        borgarnes  64.5383  -21.9206     10.03        83         100
# 3          stanley  54.8680   -1.6985     14.29        85          20
# 4         chubbuck  42.9208 -112.4661     12.13        56           0
# 10          bethel  41.3712  -73.4140     20.79        31           0
# 11          tobelo   1.7284  128.0095     26.67        83          99
#
#          Wind Speed Country        Date
# City_ID
# 1              1.66      IS  1683659500
# 3              1.03      GB  1683659500
# 4              3.60      US  1683659500
# 10             4.63      US  1683659326
# 11             1.44      ID  1683659502

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.85        96         100
# 2               andergrove -21.0833  149.1833     10.36        57          63
# 5                adamstown -25.0660 -130.1015     21.91        52          60
# 6           margaret river -33.9500  115.0667     18.56        75         100
# 7            blackmans bay -43.0167  147.3167      8.18        84          83
#
#          Wind Speed Country        Date
# City_ID
# 0             10.29      TF  1683659500
# 2              4.99      AU  1683659500
# 5              5.69      PN  1683659501
# 6             10.84      AU  1683659501
# 7              5.01      AU  1683659501

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.85        96         100
# 2               andergrove -21.0833  149.1833     10.36        57          63
# 5                adamstown -25.0660 -130.1015     21.91        52          60
# 6           margaret river -33.9500  115.0667     18.56        75         100
# 7            blackmans bay -43.0167  147.3167      8.18        84          83
#
#          Wind Speed Country        Date
# City_ID
# 0             10.29      TF  1683659500
# 2              4.99      AU  1683659500
# 5              5.69      PN  1683659501
# 6             10.84      AU  1683659501
# 7              5.01      AU  1683659501

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
corr=round(st.pearsonr(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Temperature Linear Regression Northern Hemispheres')
plt.show()

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
corr=round(st.pearsonr(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Temperature Linear Regression Southern Hemispheres')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:Temperatures between the southern hemisphere and the northern hemisphere almost mirror each other.  But that makes since since the sun would be in the northern and southern hemisperes at the opposite times of the year.  As you move away from the equator in the north the temperatures fall while when you move away from the equator in the south the temperatures rise.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
corr=round(st.pearsonr(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity Linear Regression Northern Hemispheres')
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
corr=round(st.pearsonr(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity Linear Regression Southern Hemispheres')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:  The humidity varies much more with a broader range between high and low in the northern hemispere than in the southern hemispere.  Althoug

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
corr=round(st.pearsonr(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness Linear Regression Northern Hemispheres')
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
corr=round(st.pearsonr(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness Linear Regression Southern Hemispheres')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:  The further north you go in the northern hemisphere the cloudier it gets.  However, in the southern hemispere the cloudiness remains pretty stable.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
corr=round(st.pearsonr(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Windspeed Linear Regression Northern Hemispheres')
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
corr=round(st.pearsonr(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])[0],2)
(slope,intercept,rvalue,pvalue,stderr) = st.linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,color='green')
plt.annotate(line_eq,(0,50),fontsize=25,color="green")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Windspeed Linear Regression Southern Hemispheres')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:Windspeeds reamin farily constant throughout the world... slightly more variation as you move furhter south of the equator.
